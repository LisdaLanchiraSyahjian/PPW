# %% [markdown]
# # Crawling Portal Tugas Akhir Universitas Trunojoyo Madura

# %%
# !pip install builtwith
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for builtwith: filename=builtwith-1.3.4-py3-none-any.whl size=36077 sha256=90e3d47b2d35c850d07effa11971ecd8ebc660560a3f44dd2d25d5e62bf01f0f
#   Stored in directory: /root/.cache/pip/wheels/7f/2d/b2/606e3df914d4aeeab99c4a4e3e9a61673d2293c2e346db00c8
# Successfully built builtwith
# ...

# %%
import builtwith

# Analisis teknologi yang digunakan
res = builtwith.parse('https://pta.trunojoyo.ac.id')
print(res)
# Out:
# {'web-servers': ['Nginx'], 'javascript-frameworks': ['jQuery', 'jQuery UI']}

# %% [markdown]
# ##Crawling Link Dataset

# %%
import requests
from bs4 import BeautifulSoup

def crawl_website(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad status codes

        soup = BeautifulSoup(response.content, 'html.parser')

        # Ambil semua judul h1, h2, h3
        headings = soup.find_all(['h1', 'h2', 'h3'])
        for heading in headings:
            print(f"{heading.name}: {heading.get_text()}")

        # Ambil semua link
        links = soup.find_all('a', href=True)
        for link in links:
            print(f"URL: {link['href']} | Teks: {link.get_text()}")

    except requests.exceptions.RequestException as e:
        print(f"Terjadi kesalahan saat mengakses {url}: {e}")

# Gunakan fungsi
crawl_website("https://pta.trunojoyo.ac.id/")
# Out:
# h2: Daftar Karya Ilmiah
# URL: index.html | Teks:
# URL: # | Teks: 14677Journal
# URL: https://pta.trunojoyo.ac.id/ | Teks: Beranda
# URL: https://pta.trunojoyo.ac.id/c_search/ | Teks: Pencarian
# URL: https://pta.trunojoyo.ac.id/c_template/ | Teks: Download
# URL: https://library.trunojoyo.ac.id/detil.php?id=23 | Teks: Petunjuk Upload
# URL: https://pta.trunojoyo.ac.id/c_contact/ | Teks: Kontak
# URL: # | Teks: STRATEGI PENGEMBANGAN MAKANAN DAN MINUMAN KHAS PULAU GILIGENTING GUNA MENDUKUNG PARIWISATA BERKELANJUTAN
# URL: https://pta.trunojoyo.ac.id/welcome/detail/170361100003 | Teks: Selengkapnya
# URL: # | Teks: PERUMUSAN SANKSI PIDANA BAGI MASYARAKAT SEKITAR HUTAN YANG MELAKUKAN PENCURIAN KAYU MILIK NEGARA DALAM UNDANG-UNDANG NOMOR 18 TAHUN 2013
# URL: https://pta.trunojoyo.ac.id/welcome/detail/170111100053 | Teks: Selengkapnya
# ...

# %%
import requests
from bs4 import BeautifulSoup

def crawl_website(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad status codes

        soup = BeautifulSoup(response.content, 'html.parser')

        # Ambil semua judul h1, h2, h3
        headings = soup.find_all(['h1', 'h2', 'h3'])
        for heading in headings:
            print(f"{heading.name}: {heading.get_text()}")

        # Ambil semua link
        links = soup.find_all('a', href=True)
        for link in links:
            print(f"URL: {link['href']} | Teks: {link.get_text()}")

    except requests.exceptions.RequestException as e:
        print(f"Terjadi kesalahan saat mengakses {url}: {e}")

# Gunakan fungsi
crawl_website("https://pta.trunojoyo.ac.id/welcome/index/2")
# Out:
# h2: Daftar Karya Ilmiah
# URL: index.html | Teks:
# URL: # | Teks: 14677Journal
# URL: https://pta.trunojoyo.ac.id/ | Teks: Beranda
# URL: https://pta.trunojoyo.ac.id/c_search/ | Teks: Pencarian
# URL: https://pta.trunojoyo.ac.id/c_template/ | Teks: Download
# URL: https://library.trunojoyo.ac.id/detil.php?id=23 | Teks: Petunjuk Upload
# URL: https://pta.trunojoyo.ac.id/c_contact/ | Teks: Kontak
# URL: # | Teks: ANALISIS KANDUNGAN TIMBAL (Pb) UDANG REBON (Acetes sp) HASIL TANGKAPAN DI PERAIRAN SOCCAH KABUPATEN BANGKALAN
# URL: https://pta.trunojoyo.ac.id/welcome/detail/160351100011 | Teks: Selengkapnya
# URL: # | Teks: Analisis Wacana Media Online Detik.com dalam Memberitakan Peristiwa Kerusuhan Mahasiswa Papua di Surabaya
# URL: https://pta.trunojoyo.ac.id/welcome/detail/160521100059 | Teks: Selengkapnya
# URL: # | Teks: DETEKSI OBJEK MANUSIA BERBASIS ONE STAGE DETECTOR MENGGUNAKAN ALGORITMA YOU ONLY LOOK ONCE VERSI 2 (YOLOv2)
# ...

# %%
# !pip install requests
# !pip install beautifulsoup4
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from IPython.display import display

def ptaa():
    data = {
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak": [],
        "prodi": []
    }

    prodi_urls = {
        "Ilmu Hukum": "https://pta.trunojoyo.ac.id/c_search/byprod/1",
        "Magister Ilmu Hukum": "https://pta.trunojoyo.ac.id/c_search/byprod/24",
        "Teknologi Industri Pertanian": "https://pta.trunojoyo.ac.id/c_search/byprod/2",
        "Agribisnis": "https://pta.trunojoyo.ac.id/c_search/byprod/3",
        "Agroteknologi": "https://pta.trunojoyo.ac.id/c_search/byprod/4",
        "Ilmu Kelautan": "https://pta.trunojoyo.ac.id/c_search/byprod/5",
        "Manajemen Sumberdaya Perairan": "https://pta.trunojoyo.ac.id/c_search/byprod/35",
        "Magister Pengelolaan Sumber Daya Alam": "https://pta.trunojoyo.ac.id/c_search/byprod/37",
        "Ekonomi Pembangunan": "https://pta.trunojoyo.ac.id/c_search/byprod/6",
        "Manajemen": "https://pta.trunojoyo.ac.id/c_search/byprod/7",
        "Akuntansi": "https://pta.trunojoyo.ac.id/c_search/byprod/8",
        "D3 Akuntansi": "https://pta.trunojoyo.ac.id/c_search/byprod/21",
        "Magister Manajemen": "https://pta.trunojoyo.ac.id/c_search/byprod/22",
        "Magister Akuntansi": "https://pta.trunojoyo.ac.id/c_search/byprod/25",
        "D3 Enterpreneurship": "https://pta.trunojoyo.ac.id/c_search/byprod/26",
        "Magister Ilmu Ekonomi": "https://pta.trunojoyo.ac.id/c_search/byprod/36",
        "Doktor Ilmu Manajemen": "https://pta.trunojoyo.ac.id/c_search/byprod/41",
        "Teknik Industri": "https://pta.trunojoyo.ac.id/c_search/byprod/9",
        "Teknik Informatika": "https://pta.trunojoyo.ac.id/c_search/byprod/10",
        "Manajemen Informatika": "https://pta.trunojoyo.ac.id/c_search/byprod/11",
        "Teknik Multimedia Dan Jaringan": "https://pta.trunojoyo.ac.id/c_search/byprod/19",
        "Mekatronika": "https://pta.trunojoyo.ac.id/c_search/byprod/20",
        "Teknik Elektro": "https://pta.trunojoyo.ac.id/c_search/byprod/23",
        "Sistem Informasi": "https://pta.trunojoyo.ac.id/c_search/byprod/31",
        "Teknik Mesin": "https://pta.trunojoyo.ac.id/c_search/byprod/32",
        "Teknik Mekatronika": "https://pta.trunojoyo.ac.id/c_search/byprod/33",
        "Sosiologi": "https://pta.trunojoyo.ac.id/c_search/byprod/12",
        "Ilmu Komunikasi": "https://pta.trunojoyo.ac.id/c_search/byprod/13",
        "Psikologi": "https://pta.trunojoyo.ac.id/c_search/byprod/14",
        "Sastra Inggris": "https://pta.trunojoyo.ac.id/c_search/byprod/15",
        "Ekonomi Syariah": "https://pta.trunojoyo.ac.id/c_search/byprod/16",
        "Hukum Bisnis Syariah": "https://pta.trunojoyo.ac.id/c_search/byprod/17",
        "PGSD": "https://pta.trunojoyo.ac.id/c_search/byprod/18",
        "Pendidikan Bhs Dan Sastra Indonesia": "https://pta.trunojoyo.ac.id/c_search/byprod/27",
        "Pendidikan Informatika": "https://pta.trunojoyo.ac.id/c_search/byprod/28",
        "Pendidikan IPA": "https://pta.trunojoyo.ac.id/c_search/byprod/29",
        "PGPAUD": "https://pta.trunojoyo.ac.id/c_search/byprod/30",
        "Pendidikan Profesi Guru": "https://pta.trunojoyo.ac.id/c_search/byprod/38",
        "MBKM": "https://pta.trunojoyo.ac.id/c_search/byprod/99",
        "Magister Pendidikan Dasar": "https://pta.trunojoyo.ac.id/c_search/byprod/39",
        "Doktor Pengelolaan Sumber Daya Alam": "https://pta.trunojoyo.ac.id/c_search/byprod/40"
    }

    # looping semua prodi
    for nama_prodi, prodi_url in prodi_urls.items():
        for i in range(1, 6):  # 5 halaman per prodi
            url = f"{prodi_url}/{i}"
            r = requests.get(url)
            soup = BeautifulSoup(r.content, "html.parser")
            jurnals = soup.select('li[data-cat="#luxury"]')

            for jurnal in jurnals:
                response = requests.get(jurnal.select_one('a.gray.button')['href'])
                soup1 = BeautifulSoup(response.content, "html.parser")
                isi = soup1.select_one('div#content_journal')

                judul = isi.select_one('a.title').text.strip()

                penulis = isi.select_one('span:-soup-contains("Penulis")').text.split(' : ')[1].strip()
                pembimbing_pertama = isi.select_one('span:-soup-contains("Dosen Pembimbing I")').text.split(' : ')[1].strip()
                pembimbing_kedua = isi.select_one('span:-soup-contains("Dosen Pembimbing II")').text.split(' :')[1].strip()

                abstrak = isi.select_one('p[align="justify"]').text.strip()
                if abstrak == '':
                    abstrak = ' '.join(isi.find('p').findNext('p').stripped_strings).capitalize()

                data["penulis"].append(penulis)
                data["judul"].append(judul)
                data["pembimbing_pertama"].append(pembimbing_pertama)
                data["pembimbing_kedua"].append(pembimbing_kedua)
                data["abstrak"].append(abstrak)
                data["prodi"].append(nama_prodi)

    df = pd.DataFrame(data)
    df.to_csv("pta.csv", index=False)

    display(df)  # tampil rapi di notebook
    return df

# %%
ptaa()
# Out:
# /tmp/ipython-input-3855695588.py:81: DeprecationWarning: Call to deprecated method findNext. (Replaced by find_next) -- Deprecated since version 4.0.0.
#   abstrak = ' '.join(isi.find('p').findNext('p').stripped_strings).capitalize()
#                               penulis  \
# 0                 Dyah Ayu Citra Seza
# 1                    Maulina Nurlaily
# 2                 Moh. Samsul Hidayat
# 3    TOMMY ADITYA PARLINDUNGAN MARBUN
# 4                  RICA YENA IMADHORA
# ..                                ...
# 776                  WIDYA SULISTIANI
# 777                     Siti Mardiyah
# 778                      Riana Rahayu
# 779                       dwi astutik
# 780                 Ayu Ratna Pratiwi
#
#                                                  judul  \
# 0    Implementasi Fungsi Legislasi Dewan Perwakilan...
# 1    Pertanggungjawaban Pidana Direksi BUMN (Perser...
# 2    Analisis Terhadap Kekosongan Hukum dalam Penga...
# ...

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

# Konfigurasi
URL = "https://lisdalanchirasyahjian.github.io/PPW/intro.html"  # Website target
FOLDER_NAME = "gambar"             # Folder untuk simpan gambar
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
}

# Buat folder jika belum ada
if not os.path.exists(FOLDER_NAME):
    os.makedirs(FOLDER_NAME)
    print(f"Folder '{FOLDER_NAME}' berhasil dibuat.")

# Ambil halaman web
try:
    response = requests.get(URL, headers=HEADERS, timeout=10)
    response.raise_for_status()
except requests.exceptions.RequestException as e:
    print(f"Gagal mengakses {URL}: {e}")
    exit()

# Parse HTML dengan BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Cari semua tag <img>
images = soup.find_all('img')
print(f"Ditemukan {len(images)} gambar di halaman {URL}.")

# List untuk menyimpan URL gambar
image_urls = []

for i, img in enumerate(images):
    # Ambil atribut src
    src = img.get('src')
    if not src:
        print(f"Gambar ke-{i+1} tidak memiliki atribut 'src', dilewati.")
        continue

    # Konversi URL relatif ke absolut
    img_url = urljoin(URL, src)
    image_urls.append(img_url)

    # Ambil nama file dari URL
    parsed_url = urlparse(img_url)
    filename = os.path.basename(parsed_url.path)

    # Validasi nama file
    if not filename or '.' not in filename:
        ext = '.jpg'
        filename = f"image_{i+1}{ext}"

    # Pastikan ekstensi file valid
    valid_exts = ('.png', '.jpg', '.jpeg', '.gif', '.webp', '.svg')
    if not filename.lower().endswith(valid_exts):
        filename += '.jpg'

    # Path lokal
    file_path = os.path.join(FOLDER_NAME, filename)

    # Download gambar
    try:
        img_response = requests.get(img_url, headers=HEADERS, timeout=10)
        img_response.raise_for_status()

        with open(file_path, 'wb') as f:
            f.write(img_response.content)

        print(f"Berhasil download: {filename} -> {file_path}")

    except Exception as e:
        print(f"Gagal download {img_url}: {e}")

# Ringkasan
print("\nCrawling selesai!")
print(f"Semua gambar disimpan di: ./{FOLDER_NAME}")
print(f"Total gambar diproses: {len(image_urls)}")
# Out:
# Folder 'gambar' berhasil dibuat.
# Ditemukan 2 gambar di halaman https://lisdalanchirasyahjian.github.io/PPW/intro.html.
# Berhasil download: foto.png -> gambar/foto.png
# Berhasil download: foto.png -> gambar/foto.png
#
# Crawling selesai!
# Semua gambar disimpan di: ./gambar
# Total gambar diproses: 2
